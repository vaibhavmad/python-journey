# %% [markdown]
# ## Covered in this section:
# 1. Intro to Object-Oriented Programming with Python
# 2. More about classes and objects
# 3. So... sum(), int(), str(), len(), what else is there?
# 3. Parameter naming in Python
# 4. Magic methods in Python
# 5. Inheritance in Python
# 6. The @property decorator
# 7. @classmethod and @staticmethod in Python
# 8. More @classmethod and @staticmethod examples

# %% [markdown]
# For now, skipping this section as most of it looks like introduction only. For OOP, adding one more course to the journey, which is in another folder in this directory.
